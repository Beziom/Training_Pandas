# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
data = pd.DataFrame(data=np.random.rand(4, 4) * 100000,
                    index=["I kw.", "II kw.", "III kw.", "IV kw."],
                    columns=["Wschód", "Zachód", "Północ", "Południe"])
data
# Out:
#                Wschód        Zachód        Północ      Południe
# I kw.    42143.771255  71139.407393  16091.958146  24651.884939
# II kw.   91341.699824  23587.154401  96556.001730  67268.941094
# III kw.  86439.975261  38529.723284  41260.703644  80209.773795
# IV kw.   73561.987446  58219.759594  23563.372995  22431.795290

# %%
data.plot()
# Out:
# <AxesSubplot: >

# %%
"Setting engine for plot drawing to plotly"
pd.options.plotting.backend = "plotly"

# %%
data.plot()

# %%
data.plot.bar(barmode = "group")

# %%
data.plot.barh()

# %%
data.plot.hist()

# %%
data.plot.box()

# %%
data.plot.area()
